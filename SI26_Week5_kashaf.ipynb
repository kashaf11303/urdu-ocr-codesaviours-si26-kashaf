# %% [markdown]
# <a href="https://colab.research.google.com/github/kashaf11303/urdu-ocr-codesaviours-si26-kashaf/blob/main/SI26_Week5_kashaf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -lah /content/drive/MyDrive/SI26-urdu-ocr-model
# Out:
# total 1.3G
# -rw------- 1 root root 4.6K Aug  7 11:08 config.json
# -rw------- 1 root root  185 Aug  7 11:08 generation_config.json
# -rw------- 1 root root 446K Aug  7 11:08 merges.txt
# -rw------- 1 root root 1.3G Aug  7 11:08 model.safetensors
# -rw------- 1 root root  364 Aug  7 11:08 preprocessor_config.json
# -rw------- 1 root root  957 Aug  7 11:08 special_tokens_map.json
# -rw------- 1 root root 1.3K Aug  7 11:08 tokenizer_config.json
# -rw------- 1 root root 2.1M Aug  7 11:08 tokenizer.json
# -rw------- 1 root root 780K Aug  7 11:08 vocab.json

# %%
# !pip install -U huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.9/784.9 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 76.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.5.1
#     Uninstalling hf-xet-1.5.1:
#       Successfully uninstalled hf-xet-1.5.1
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.23.0
#     Uninstalling huggingface_hub-1.23.0:
#       Successfully uninstalled huggingface_hub-1.23.0
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>LMXJ-M88G</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center><b style='color: red;'>Login failed: Device code expired (timeout). Please try again.</b></center>

# %%
from huggingface_hub import HfApi

api = HfApi()

api.create_repo(
    repo_id="kashaf112-s/SI26-urdu-ocr-model-kashaf",
    repo_type="model",
    exist_ok=True
)

print("Repository created successfully!")
# Out:
# Repository created successfully!

# %%
from huggingface_hub import login, upload_folder

# Hugging Face login
login()

# Upload the complete model folder
upload_folder(
    folder_path="/content/drive/MyDrive/SI26-urdu-ocr-model",
    repo_id="kashaf112-s/SI26-urdu-ocr-model-kashaf",
    repo_type="model"
)

print("Model uploaded successfully!")

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 60.9 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
# Out:
# Overwriting app.py

# %%
# !pip install easyocr

import streamlit as st
import easyocr
from PIL import Image
import numpy as np

st.set_page_config(page_title="Urdu OCR - Code Saviours SI-26", page_icon="📝")
st.title("Urdu OCR — Code Saviours SI-26")
st.write("Upload an image containing Urdu text and get the extracted text.")

@st.cache_resource
def load_reader():
    reader = easyocr.Reader(['ur'])   # 'ur' = Urdu language code
    return reader

reader = load_reader()

uploaded_file = st.file_uploader("Upload Urdu Image", type=["png", "jpg", "jpeg"])

if uploaded_file is not None:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Uploaded Urdu Image")

    if st.button("Extract Urdu Text"):
        result = reader.readtext(np.array(image), detail=0, paragraph=True)
        text = " ".join(result)

        if text:
            st.subheader("Extracted Urdu Text")
            st.write(text)
        else:
            st.write("?????.")
# Out:
# ...
# 2026-08-16 12:24:40.039 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-16 12:24:40.040 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-16 12:24:40.104
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-08-16 12:24:40.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-16 12:24:40.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-16 12:24:40.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !streamlit run app.py &>/content/streamlit.log &
